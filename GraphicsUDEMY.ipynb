# %% [markdown]
# <a href="https://colab.research.google.com/github/bcguilherme/arquivos-legais/blob/main/GraphicsUDEMY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
base=pd.read_csv("/Volumes/Untitled/FormacaoCD/13.Pr†tica em Python/dados/trees.csv")
base.shape
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
h=np.histogram(base.iloc[:,1],bins=6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
plt.hist(base.iloc[0:,1], bins=8)
plt.title("Arvores")
plt.ylabel("Frequencia")
plt.xlabel("Altura")
# Out:
# Text(0.5, 0, 'Altura')

# %%
sns.histplot(base.iloc[0:,1],kde=False, bins=6, color="blue").set(title="Arvores")
# Out:
# [Text(0.5, 1.0, 'Arvores')]

# %%
sns.histplot(base.iloc[0:,1],kde=True, color="blue").set(title="Arvores")
# Out:
# [Text(0.5, 1.0, 'Arvores')]

# %%
sns.kdeplot(base.iloc[0:,1], color="blue").set(title="Arvores")
# Out:
# [Text(0.5, 1.0, 'Arvores')]

# %% [markdown]
# graficos de dispersao usando MATPLOTLIB.PYPLOT

# %%
plt.scatter(x=base.Girth, y=base.Volume, color="blue", facecolor="none", marker= ".")
plt.title("Arvores")
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.plot(base.Girth, base.Volume)
plt.title("Arvores")
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
sns.regplot(x=base.Girth, y=base.Volume, data=base, x_jitter =0.3, fit_reg=True, color="black");

# %%
base.corr()
# Out:
#                Girth   Height    Volume  Y_Previsto   residuo
# Girth       1.000000  0.51928  0.967119    1.000000  1.000000
# Height      0.519280  1.00000  0.598250    0.519280  0.519280
# Volume      0.967119  0.59825  1.000000    0.967119  0.967119
# Y_Previsto  1.000000  0.51928  0.967119    1.000000  1.000000
# residuo     1.000000  0.51928  0.967119    1.000000  1.000000

# %%
x= [15,18,20,25,30,44]
y=[240,255,270,283,300,310]
list_tuple=list(zip(x,y))

dataframe=pd.DataFrame(list_tuple, columns=["X", "Y"])
dataframe

dataframe.corr()
# Out:
#           X         Y
# X  1.000000  0.923781
# Y  0.923781  1.000000

# %%
base.head()
y=base.Volume
x=sm.add_constant(base.Girth)

# %%
regressor_result=sm.OLS(y,x).fit()

# %%
print(regressor_result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Volume   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     419.4
# Date:                Mon, 29 May 2023   Prob (F-statistic):           8.64e-19
# Time:                        23:14:39   Log-Likelihood:                -87.822
# No. Observations:                  31   AIC:                             179.6
# Df Residuals:                      29   BIC:                             182.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -36.9435      3.365    -10.978      0.000     -43.826     -30.061
# ...

# %%
base["Y_Previsto"]=regressor_result.predict()
base["residuo"]=base["Y_Previsto"]-base["Girth"]
base
# Out:
#     Girth  Height  Volume  Y_Previsto    residuo
# 0     8.3      70    10.3    5.103149  -3.196851
# 1     8.6      65    10.3    6.622906  -1.977094
# 2     8.8      63    10.2    7.636077  -1.163923
# 3    10.5      72    16.4   16.248033   5.748033
# 4    10.7      81    18.8   17.261205   6.561205
# 5    10.8      83    19.7   17.767790   6.967790
# 6    11.0      66    15.6   18.780962   7.780962
# 7    11.0      75    18.2   18.780962   7.780962
# 8    11.1      80    22.6   19.287547   8.187547
# 9    11.2      75    19.9   19.794133   8.594133
# 10   11.3      79    24.2   20.300718   9.000718
# 11   11.4      76    21.0   20.807304   9.407304
# 12   11.4      76    21.4   20.807304   9.407304
# 13   11.7      69    21.3   22.327061  10.627061
# 14   12.0      75    19.1   23.846818  11.846818
# 15   12.9      74    22.2   28.406089  15.506089
# 16   12.9      85    33.8   28.406089  15.506089
# 17   13.3      86    27.4   30.432431  17.132431
# ...

# %%
base["residuo"]=base["Y_Previsto"]-base["Girth"]
base
# Out:
#     Girth  Height  Volume  Y_Previsto    residuo
# 0     8.3      70    10.3    5.103149  -3.196851
# 1     8.6      65    10.3    6.622906  -1.977094
# 2     8.8      63    10.2    7.636077  -1.163923
# 3    10.5      72    16.4   16.248033   5.748033
# 4    10.7      81    18.8   17.261205   6.561205
# 5    10.8      83    19.7   17.767790   6.967790
# 6    11.0      66    15.6   18.780962   7.780962
# 7    11.0      75    18.2   18.780962   7.780962
# 8    11.1      80    22.6   19.287547   8.187547
# 9    11.2      75    19.9   19.794133   8.594133
# 10   11.3      79    24.2   20.300718   9.000718
# 11   11.4      76    21.0   20.807304   9.407304
# 12   11.4      76    21.4   20.807304   9.407304
# 13   11.7      69    21.3   22.327061  10.627061
# 14   12.0      75    19.1   23.846818  11.846818
# 15   12.9      74    22.2   28.406089  15.506089
# 16   12.9      85    33.8   28.406089  15.506089
# 17   13.3      86    27.4   30.432431  17.132431
# ...

# %%
base1=pd.read_csv("/Volumes/Untitled/FormacaoCD/13.Pr†tica em Python/dados/co2.csv")
base1.shape
base1.head(1)
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0

# %%
x=base1.conc
y=base1.uptake

# %%
unicos=list(set(base1.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
for i in range(len(unicos)):
    indice=base1.Treatment==unicos[i]
    plt.scatter(x[indice], y[indice], label= unicos[i])
plt.legend(loc= "lower right");

# %%
base.head(2)
plt.scatter(base.Girth, base.Height, marker=".")

# %%
plt.scatter(base.Height, base.Volume, marker=".")

# %%
plt.scatter(base.Girth, base.Volume, marker=".")

# %%
plt.hist(base.Volume, color="blue", bins=6)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(1, figsize=(8,6))
plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume, marker=".")
plt.subplot(2,2,2)
plt.scatter(base.Girth, base.Height, marker=".")
plt.subplot(2,2,3)
plt.scatter(base.Height ,base.Volume, marker=".")
plt.subplot(2,2,4)
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(1, figsize=(6,6))
plt.subplot(2,2,1)
plt.boxplot(base.Volume, vert=False, showfliers=True, notch=False, patch_artist=True)
plt.subplot(2,2,2)
plt.boxplot(base.Height, vert=False, showfliers=True)
plt.subplot(2,2,3)
plt.boxplot(base.Girth, vert=False, showfliers=True)
plt.title("Arvores")
plt.xlabel("Volume")
# Out:
# Text(0.5, 0, 'Volume')

# %%
base3=pd.read_csv("/Volumes/Untitled/FormacaoCD/13.Pr†tica em Python/dados/insect.csv")
base3.shape
base3.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
base3_agrupado=base3.groupby(["spray"])["count"].sum()
base3_agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
base3_agrupado.plot.bar(color=['blue', "grey","yellow", "orange", "purple", "red"])
# Out:
# <AxesSubplot:xlabel='spray'>

# %%
base3_agrupado.plot.pie()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.boxplot(data=base.Volume, orient="v", color="grey").set_title("Arvores")
# Out:
# Text(0.5, 1.0, 'Arvores')

# %%
sns.boxenplot(data= base)
# Out:
# <AxesSubplot:>

# %%
base4=pd.read_csv("/Volumes/Untitled/FormacaoCD/13.Pr†tica em Python/dados/chicken.csv")
base4.shape
base4.head()


base4_agrupado=base4.groupby(["feed"]).sum()
base4_agrupado
# Out:
#            weight
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947

# %%
#novo dataframe somente com Hordebean
teste=base4.loc[base4["feed"]=="horsebean"]
teste

sns.histplot(data=base4.loc[base4["feed"]=="horsebean"].weight,kde=True).set(title="horsebean")
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
sns.histplot(data=base4.loc[base4["feed"]=="linseed"].weight,kde=True).set(title="linseed")
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
sns.histplot(data=base4.loc[base4["feed"]=="casein"].weight,kde=True).set(title="casein")
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
display(base4_agrupado)

sns.histplot(data=base4.loc[base4["feed"]=="meatmeal"].weight,kde=True).set(title="meatmeal")
# Out:
#            weight
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# [Text(0.5, 1.0, 'meatmeal')]

# %%
sns.histplot(data=base4.loc[base4["feed"]=="sunflower"].weight,kde=True).set(title="sunflower")
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
sns.histplot(data=base4.loc[base4["feed"]=="soybean"].weight,kde=True).set(title="soybean")
# Out:
# [Text(0.5, 1.0, 'soybean')]

# %%
#usado subplot para agrupar os graficos
plt.figure(1)
plt.subplot(3,2,1)
sns.histplot(data=base4.loc[base4["feed"]=="linseed"].weight,kde=True).set(title="linseed")
plt.subplot(3,2,2)
sns.histplot(data=base4.loc[base4["feed"]=="soybean"].weight,kde=True).set(title="soybean")
plt.subplot(3,2,3)
sns.histplot(data=base4.loc[base4["feed"]=="sunflower"].weight,kde=True).set(title="sunflower")
plt.subplot(3,2,4)
sns.histplot(data=base4.loc[base4["feed"]=="horsebean"].weight,kde=True).set(title="horsebean")
plt.subplot(3,2,5)
sns.histplot(data=base4.loc[base4["feed"]=="casein"].weight,kde=True).set(title="casein")
plt.subplot(3,2,6)
sns.histplot(data=base4.loc[base4["feed"]=="linseed"].weight,kde=True).set(title="linseed")
#para nao haver sobreposicao de layout
plt.tight_layout()

# %%
base1
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]

# %% [markdown]
# atividade UDEMy

# %%
gaucho=pd.read_csv("/Volumes/Untitled/FormacaoCD/13.Pr†tica em Python/dados/dados.csv", sep=";")
gaucho.shape

gaucho.head()

gaucho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CODIGO        187 non-null    int64
#  1   MUNICIPIO     187 non-null    object
#  2   PIB           187 non-null    float64
#  3   VALOREMPENHO  187 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
gaucho.describe()
# Out:
#            CODIGO            PIB  VALOREMPENHO
# count  187.000000     187.000000  1.870000e+02
# mean   247.155080   19808.741337  1.299844e+05
# std    138.750385   16984.223244  1.615491e+05
# min      1.000000    8236.630000  1.721300e+02
# 25%    141.000000   13621.455000  5.251718e+04
# 50%    242.000000   17206.190000  8.422816e+04
# 75%    372.500000   21429.165000  1.538961e+05
# max    496.000000  223848.220000  1.442760e+06

# %%
gaucho.isna().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
gaucho
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
sns.histplot(data=gaucho.PIB, kde=True)
plt.subplot(1,2,2)
sns.histplot(data=gaucho.VALOREMPENHO, kde= True)
# Out:
# <AxesSubplot:xlabel='VALOREMPENHO', ylabel='Count'>

# %%
#ordernado por PIB iloc[:,1:3] usando iloc, todas as linhasm , '[,1:3], selecionando apenas as colunas
# 1 a 3 sendo q coluna 3 nao entra na selecao
ordenado =gaucho.sort_values("PIB").head(10)
#agrupado
ordenado = ordenado.iloc[:,1:3]
ordenado
ordenado.plot.bar(x="MUNICIPIO", y="PIB", color="blue");

# %%
#ordenando o valor empenho, e depois usando iloc[:,[1:3]], selecionando todas as linhas,
#mas colocando a posicao [:,[1:3]], selecionamos apenas a coluna 1 e 3 da tabela
ordenado_empeenho=gaucho.sort_values("VALOREMPENHO").head(10)
#ordenado_empeenho
ordenado_empeenho=ordenado_empeenho.iloc[:,[1,3]]
ordenado_empeenho.plot.bar(x="MUNICIPIO", y="VALOREMPENHO", color="blue")
# Out:
# <AxesSubplot:xlabel='MUNICIPIO'>

# %%
sns.boxplot(data=gaucho.PIB, orient="h")
# Out:
# <AxesSubplot:>
